# %% [markdown]
# # **Applying Advanced Transformations**

# %% [markdown]
# **Name:** **Derek Overton**
#
# **Date:** **3/2/2023**
#
# **Assignment:** **Applying Advanced Transformations**

# %% [markdown]
# # **Imports**

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
import os, json, math, time
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # **Load Data**

# %%
# Upload Superhero Info data:
shi = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vS1ZstYLwFgwhZnqDsPjtnlHYhJp_cmW55J8JD5mym0seRsaem3px7QBtuFF0LiI7z1PLCkVKAkdO7J/pub?output=csv')

# %%
# Show Superhero Info dataframe:
shi.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
shp = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSzdWOBaXOoz52vPmCFV5idNlDBohLY1Lsbc1IfZIZQ7cV_aNB2wYBfhF49uE1TaO1B5MQCGWiNrFfd/pub?output=csv')

# %%
# Show Superhero Powers dataframe
shp.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# # **Clean and Combine into one final DataFrame**

# %%
# Get information about dataframes:
shi.info()
shp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB

# %%
shi['Hero|Publisher'].head()
# Out:
# 0            A-Bomb|Marvel Comics
# 1    Abe Sapien|Dark Horse Comics
# 2              Abin Sur|DC Comics
# 3       Abomination|Marvel Comics
# 4     Absorbing Man|Marvel Comics
# Name: Hero|Publisher, dtype: object

# %%
shi['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
## save the 2 new columns into the dataframe
shi[['Hero','Publisher']] = shi['Hero|Publisher'].str.split('|',expand=True)
shi.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
## drop the original column 
shi = shi.drop(columns=['Hero|Publisher'])
shi.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero          Publisher
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb      Marvel Comics
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien  Dark Horse Comics

# %%
# merge the two dataframes on the 'Hero' column
merged_df = pd.merge(shi, shp, left_on='Hero', right_on='hero_names')

# %%
merged_df
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color                                  Measurements             Hero  \
# 0      Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}           A-Bomb
# 1         blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}       Abe Sapien
# 2          red   {'Height': '185.0 cm', 'Weight': '90.0 kg'}         Abin Sur
# 3      Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      Abomination
# 4      Unknown  {'Height': '193.0 cm', 'Weight': '122.0 kg'}    Absorbing Man
# ..         ...                                           ...              ...
# 458    Unknown   {'Height': '183.0 cm', 'Weight': '83.0 kg'}     Yellowjacket
# 459    Unknown   {'Height': '165.0 cm', 'Weight': '52.0 kg'}  Yellowjacket II
# 460      green    {'Height': '66.0 cm', 'Weight': '17.0 kg'}             Yoda
# 461    Unknown   {'Height': '170.0 cm', 'Weight': '57.0 kg'}          Zatanna
# 462    Unknown   {'Height': '185.0 cm', 'Weight': '81.0 kg'}             Zoom
#
#              Publisher       hero_names  \
# 0        Marvel Comics           A-Bomb
# 1    Dark Horse Comics       Abe Sapien
# 2            DC Comics         Abin Sur
# 3        Marvel Comics      Abomination
# 4        Marvel Comics    Absorbing Man
# ..                 ...              ...
# 458      Marvel Comics     Yellowjacket
# 459      Marvel Comics  Yellowjacket II
# 460       George Lucas             Yoda
# 461          DC Comics          Zatanna
# 462          DC Comics             Zoom
#
#                                                 Powers
# 0    Accelerated Healing,Durability,Longevity,Super...
# 1    Agility,Accelerated Healing,Cold Resistance,Du...
# 2                                   Lantern Power Ring
# 3    Accelerated Healing,Intelligence,Super Strengt...
# 4    Cold Resistance,Durability,Energy Absorption,S...
# ..                                                 ...
# 458               Size Changing,Animal Oriented Powers
# 459                 Flight,Energy Blasts,Size Changing
# 460  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 461  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 462  Super Speed,Intangibility,Time Travel,Time Man...
#
# [463 rows x 11 columns]

# %%
merged_df['Measurements'].apply(pd.Series)
# Out:
#                                                 0
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# ..                                            ...
# 458   {'Height': '183.0 cm', 'Weight': '83.0 kg'}
# 459   {'Height': '165.0 cm', 'Weight': '52.0 kg'}
# 460    {'Height': '66.0 cm', 'Weight': '17.0 kg'}
# 461   {'Height': '170.0 cm', 'Weight': '57.0 kg'}
# 462   {'Height': '185.0 cm', 'Weight': '81.0 kg'}
#
# [463 rows x 1 columns]

# %%
# Slice out a single test Measurement
test_ms = merged_df.loc[1,'Measurements']
test_ms
# Out:
# "{'Height': '191.0 cm', 'Weight': '65.0 kg'}"

# %%
# Make a list of all characters to replace
to_replace = ['(',')']
# run a loop to replace all of the characters in the list at once
for char in to_replace:
    merged_df['Measurements'] = merged_df['Measurements'].str.replace(char,'',regex=False)
    
merged_df['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
json.loads(merged_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 json.loads(merged_df)
#
# File ~\anaconda3\envs\dojo-env\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not DataFrame

# %%
# Check the signle record
test_ms

# %%
# replace single ' with "
test_ms = test_ms.replace("''", '"')
test_ms

# %%
## replace ' with " (entire column)
merged_df['Measurements'] = merged_df['Measurements'].str.replace("'",'"')

## drop NaN values
merged_df.dropna(subset=['Measurements'], inplace=True)

## apply json.loads
merged_df['Measurements'] = merged_df['Measurements'].apply(json.loads)

# %%
## slice out a single test coordinate
merged_df = merged_df.loc[5,'Measurements']
type(test_ms)

# %%
## use .apply pd.Series to convert a dict to columns
merged_df['Measurements'].apply(pd.Series)

# %%
## Concatenate the 2 new columns and drop the original.
merged_df = pd.concat([merged_df,merged_df['Measurements'].apply(pd.Series)],axis =1)
merged_df =merged_df.drop(columns= 'Measurements')
merged_df.head(2)

# %%
powers = set()
for powers_list in hero_df['Powers'].str.split(','):
    if isinstance(powers_list, float):
        continue
    for powers in powers_list:
        powers.add(powers.strip())
        
for powers in powers:
    hero_df[powers] = hero_df['Powers'].apply(lambda x: int(powers in x.split(',')))

# %% [markdown]
# ## **Compare the average weight of super powers who have Super Speed to those who do not.**

# %%
# check for existence of 'Super Speed' in the columns
if 'Super Speed' in hero_df.columns:
    # calculate average weight of heroes with 'Super Speed'
    super_speed_avg_weight = np.mean(hero_df[hero_df['Super Speed'] == True]['Weight'])
    print(f"Average weight of heroes with 'Super Speed': {super_speed_avg_weight}")

    # calculate average weight of heroes without 'Super Speed'
    no_super_speed_avg_weight = np.mean(hero_df[hero_df['Super Speed'] == False]['Weight'])
    print(f"Average weight of heroes without 'Super Speed': {no_super_speed_avg_weight}")
else:
    print("'Super Speed' not found in columns")

# %% [markdown]
# ## **What is the average height of heroes for each publisher?**

# %%
def convert_height_to_cm(height):
    if type(height) != str:
        return None
    try:
        height_cm = int(height.split()[0]) * 30.48 + int(height.split()[2]) * 2.54
        return height_cm
    except:
        return None

# %%
hero_df['Height'] = hero_df['Height'].str.replace(' cm', '').astype(float)

# %%
hero_df.groupby('Hero|Publisher')['Height'].mean()
